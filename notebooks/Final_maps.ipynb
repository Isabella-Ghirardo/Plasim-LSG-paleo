# %%
import Util
import importlib
importlib.reload(Util)
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pandas as pd
import xarray as xr
import numpy as np
import dask

# %%
infile1_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test1_ml/output/MOST_PLA.*.nc"
infile2_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test2_ml/output/MOST_PLA.*.nc"
infile3_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test3_ml/output/MOST_PLA.*.nc"
infile4_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test4_ml/output/MOST_PLA.*.nc"
infile6_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test6_ml/output/MOST_PLA.*.nc"
infile8_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test8_ml/output/MOST_PLA.*.nc"
infile12_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test12_ml/output/MOST_PLA.*.nc"
infile16_ml="/home/ighirardo/work/plasim/exp/test_pla_ml/test16_ml/output/MOST_PLA.*.nc"

# %%
infile1="/home/ighirardo/work/plasim/exp/test_pla_lsg/test1_lsg/output/MOST_PLA.*.nc"
infile2="/home/ighirardo/work/plasim/exp/test_pla_lsg/test2_lsg/output/MOST_PLA.*.nc"
infile3="/home/ighirardo/work/plasim/exp/test_pla_lsg/test3_lsg/output/MOST_PLA.*.nc"
infile4="/home/ighirardo/work/plasim/exp/test_pla_lsg/test4_lsg/output/MOST_PLA.*.nc"
infile6="/home/ighirardo/work/plasim/exp/test_pla_lsg/test6_lsg/output/MOST_PLA.*.nc"
infile8="/home/ighirardo/work/plasim/exp/test_pla_lsg/test8_lsg/output/MOST_PLA.*.nc"
infile12="/home/ighirardo/work/plasim/exp/test_pla_lsg/test12_lsg/output/MOST_PLA.*.nc"
infile16="/home/ighirardo/work/plasim/exp/test_pla_lsg/test16_lsg/output/MOST_PLA.*.nc"

# %%
infile1_lsg="/home/ighirardo/work/plasim/exp/test_h_lsg/h_lsg_1/output/MOST_LSG.*.nc"

infile3_lsg="/home/ighirardo/work/plasim/exp/test_h_lsg/h_lsg_3/output/MOST_LSG.*.nc"

infile6_lsg="/home/ighirardo/work/plasim/exp/test_h_lsg/h_lsg_6/output/MOST_LSG.*.nc"

infile12_lsg="/home/ighirardo/work/plasim/exp/test_h_lsg/h_lsg_12/output/MOST_LSG.*.nc"
infile16_lsg="/home/ighirardo/work/plasim/exp/test_h_lsg/h_lsg_16/output/MOST_LSG.*.nc"

# %%
data1ml = Util.open_mfdataset_plasim_monthly (infile1_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data2ml = Util.open_mfdataset_plasim_monthly (infile2_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data3ml = Util.open_mfdataset_plasim_monthly (infile3_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
#data4ml = Util.open_mfdataset_plasim_monthly (infile4_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data6ml = Util.open_mfdataset_plasim_monthly (infile6_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data8ml = Util.open_mfdataset_plasim_monthly (infile8_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data12ml = Util.open_mfdataset_plasim_monthly (infile12_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data16ml = Util.open_mfdataset_plasim_monthly (infile16_ml, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
# Out:
# /usr/lib/python3/dist-packages/xarray/backends/plugins.py:68: RuntimeWarning: Engine 'cfgrib' loading failed:
# xarray_plugin module needs xarray version >= 0.18+
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
data1 = Util.open_mfdataset_plasim_monthly (infile1, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data2 = Util.open_mfdataset_plasim_monthly (infile2, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data3 = Util.open_mfdataset_plasim_monthly (infile3, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data4 = Util.open_mfdataset_plasim_monthly (infile4, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data6 = Util.open_mfdataset_plasim_monthly (infile6, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data8 = Util.open_mfdataset_plasim_monthly (infile8, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data12 = Util.open_mfdataset_plasim_monthly (infile12, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data16 = Util.open_mfdataset_plasim_monthly (infile16, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)

# %%
data1_lsg = Util.open_mfdataset_plasim_monthly (infile1_lsg, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)

data3_lsg = Util.open_mfdataset_plasim_monthly (infile3_lsg, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)

data6_lsg = Util.open_mfdataset_plasim_monthly (infile6_lsg, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)

data12_lsg = Util.open_mfdataset_plasim_monthly (infile12_lsg, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
data16_lsg = Util.open_mfdataset_plasim_monthly (infile16_lsg, concat_dim="time", combine="nested", use_cftime=True, decode_times=False)
# Out:
# /usr/lib/python3/dist-packages/xarray/backends/plugins.py:68: RuntimeWarning: Engine 'cfgrib' loading failed:
# xarray_plugin module needs xarray version >= 0.18+
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %% [markdown]
# EQUILIBRIUM WITHOUT SPINUP

# %%
teq_1_ml= data1ml.tas.isel(time=range(50*12, 150*12))
teq_2_ml= data2ml.tas.isel(time=range(50*12, 150*12))
teq_3_ml= data3ml.tas.isel(time=range(50*12, 150*12))
#teq_4_ml= data4ml.tas.isel(time=range(50*12, 600*12))
teq_6_ml= data6ml.tas.isel(time=range(50*12, 150*12))
teq_8_ml= data8ml.tas.isel(time=range(50*12, 150*12))
teq_12_ml= data12ml.tas.isel(time=range(50*12, 150*12))
teq_16_ml= data16ml.tas.isel(time=range(50*12, 150*12))

# %%
teq_1= data1.tas.isel(time=range(50*12, 600*12))
teq_2= data2.tas.isel(time=range(50*12, 600*12))
teq_3= data3.tas.isel(time=range(50*12, 600*12))
#teq_4= data4.tas.isel(time=range(50*12, 600*12))
teq_6= data6.tas.isel(time=range(50*12, 600*12))
teq_8= data8.tas.isel(time=range(50*12, 600*12))
teq_12= data12.tas.isel(time=range(50*12, 600*12))
teq_16= data16.tas.isel(time=range(50*12, 600*12))

# %%
teq_1_lsg= data1_lsg.tas.isel(time=range(50*12, 600*12))
#teq_2_ml= data2ml.tas.isel(time=range(50*12, 600*12))
teq_3_lsg= data3_lsg.tas.isel(time=range(50*12, 600*12))
#teq_4_ml= data4ml.tas.isel(time=range(50*12, 600*12))
teq_6_lsg= data6_lsg.tas.isel(time=range(50*12, 600*12))
#teq_8_ml= data8ml.tas.isel(time=range(50*12, 600*12))
teq_12_lsg= data12_lsg.tas.isel(time=range(50*12, 600*12))
teq_16_lsg= data16_lsg.tas.isel(time=range(50*12, 600*12))

# %% [markdown]
# ZONAL MEAN

# %%
diff2 = Util.area_mean(teq_2_ml).compute() - Util.area_mean(teq_1).compute()
diff3 = Util.area_mean(teq_3_ml).compute() - Util.area_mean(teq_1).compute()
#diff4 = Util.area_mean(teq_4).compute() - Util.area_mean(teq_1).compute()
diff6 = Util.area_mean(teq_6_ml).compute() - Util.area_mean(teq_1).compute()
diff8 = Util.area_mean(teq_8_ml).compute() - Util.area_mean(teq_1).compute()
diff12 = Util.area_mean(teq_12_ml).compute() - Util.area_mean(teq_1).compute()
diff16 = Util.area_mean(teq_16_ml).compute() - Util.area_mean(teq_1).compute()

diff2.plot(color='green')
diff3.plot(color='blue')
#diff4.plot(color='red')
diff6.plot(color='purple')
diff8.plot(color='orange')
diff12.plot(color='brown')
diff16.plot(color='red')

plt.xlabel('Time (years)')
plt.ylabel('Difference in temperature')

plt.legend(['2x CO2', '3x CO2', '4x CO2', '6x CO2', '8x CO2', '12x CO2', '16x CO2'])
plt.title('Difference in global mean temperature for various CO2 levels')
# Out:
# Text(0.5, 1.0, 'Difference in global mean temperature for various CO2 levels')
# /home/ighirardo/.local/lib/python3.10/site-packages/nc_time_axis/__init__.py:376: CFWarning: this date/calendar/year zero convention is not supported by CF
#   cftime.datetime(

# %% [markdown]
# TIME AND ZONAL MEAN DIFFERENCE

# %%
tas_diff_1ml = teq_1_ml.mean(dim=('time', 'lon')) - teq_1_ml.mean(dim=('time', 'lon')) # 1x_ml - 1x
tas_diff_2ml = teq_2_ml.mean(dim=('time', 'lon')) - teq_1_ml.mean(dim=('time', 'lon')) # 2x_ml - 1x
tas_diff_3ml = teq_3_ml.mean(dim=('time', 'lon')) - teq_1_ml.mean(dim=('time', 'lon')) # 3x_ml - 1x
tas_diff_6ml = teq_6_ml.mean(dim=('time', 'lon')) - teq_1_ml.mean(dim=('time', 'lon')) # 6x_ml - 1x
tas_diff_8ml = teq_8_ml.mean(dim=('time', 'lon')) - teq_1_ml.mean(dim=('time', 'lon')) # 8x_ml - 1x
tas_diff_12ml = teq_12_ml.mean(dim=('time', 'lon')) - teq_1_ml.mean(dim=('time', 'lon')) # 12x_ml - 1x
tas_diff_16ml = teq_16_ml.mean(dim=('time', 'lon')) - teq_1_ml.mean(dim=('time', 'lon')) # 16x_ml - 1x

tas_diff_1ml.plot(label='1x_ml - 1x', color='black')
tas_diff_2ml.plot(label='2x_ml - 1x', color='green')
tas_diff_3ml.plot(label='3x_ml - 1x', color='blue')
tas_diff_6ml.plot(label='6x_ml - 1x', color='purple')
tas_diff_8ml.plot(label='8x_ml - 1x', color='orange')
tas_diff_12ml.plot(label='12x_ml - 1x', color='brown')
tas_diff_16ml.plot(label='16x_ml - 1x', color='pink')

plt.xlabel('Latitude')
plt.ylabel('Temperature Difference (K)')
plt.legend()
plt.title('Zonal Mean Temperature Difference for Various CO2 Levels')
plt.show()

# %%
tas_diff_1= teq_1.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 1x_ml - 1x
#tas_diff_2 = teq_2.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 2x - 1x
tas_diff_3 = teq_3.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 3x - 1x
#tas_diff_4 = teq_4.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 4x - 1x
tas_diff_6 = teq_6.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 6x - 1x
#tas_diff_8 = teq_8.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 8x - 1x
tas_diff_12 = teq_12.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 12x - 1x
tas_diff_16 = teq_16.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 16x - 1x


tas_diff_1.plot(label='1x - 1x', color='black')
tas_diff_3.plot(label='3x - 1x', color='blue')
#tas_diff_4.plot(label='4x - 1x', color='red')
tas_diff_6.plot(label='6x - 1x', color='purple')
#tas_diff_8.plot(label='8x - 1x', color='orange')
tas_diff_12.plot(label='12x - 1x', color='brown')
tas_diff_16.plot(label='16x - 1x', color='red')

plt.xlabel('Latitude')
plt.ylabel('Temperature Difference (K)')
plt.legend()
plt.title('Zonal Mean Temperature Difference for Various CO2 Levels')
plt.show()

# %%
tas_diff_1lsg = teq_1_lsg.mean(dim=('time', 'lon')) - teq_1_lsg.mean(dim=('time', 'lon')) # 1x_ml - 1x
#tas_diff_2lsg = teq_2.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 2x_ml - 1x
tas_diff_3lsg = teq_3_lsg.mean(dim=('time', 'lon')) - teq_1_lsg.mean(dim=('time', 'lon')) # 3x_ml - 1x
tas_diff_6lsg = teq_6_lsg.mean(dim=('time', 'lon')) - teq_1_lsg.mean(dim=('time', 'lon')) # 6x_ml - 1x
#tas_diff_8ml = teq_8.mean(dim=('time', 'lon')) - teq_1.mean(dim=('time', 'lon')) # 8x_ml - 1x
tas_diff_12lsg = teq_12_lsg.mean(dim=('time', 'lon')) - teq_1_lsg.mean(dim=('time', 'lon')) # 12x_ml - 1x
tas_diff_16lsg = teq_16_lsg.mean(dim=('time', 'lon')) - teq_1_lsg.mean(dim=('time', 'lon')) # 16x_ml - 1x

tas_diff_1lsg.plot(label='1x - 1x', color='black')
#tas_diff_2ml.plot(label='2x_ml - 1x', color='green')
tas_diff_3lsg.plot(label='3x - 1x', color='blue')
tas_diff_6lsg.plot(label='6x - 1x', color='purple')
#tas_diff_8ml.plot(label='8x_ml - 1x', color='orange')
tas_diff_12lsg.plot(label='12x - 1x', color='brown')
tas_diff_16lsg.plot(label='16x - 1x', color='red')

plt.xlabel('Latitude')
plt.ylabel('Temperature Difference (K)')
plt.legend()
plt.title('Zonal Mean Temperature Difference for Various CO2 Levels')
plt.show()

# %% [markdown]
# ANNUAL MEAN

# %%
annual_mean1 = Util.area_mean(teq_1_ml).groupby("time.year").mean("time")
annual_mean2 = Util.area_mean(teq_2_ml).groupby("time.year").mean("time")
annual_mean3 = Util.area_mean(teq_3_ml).groupby("time.year").mean("time")
#annual_mean4 = Util.area_mean(teq_4_ml).groupby("time.year").mean("time")
annual_mean6 = Util.area_mean(teq_6_ml).groupby("time.year").mean("time")
annual_mean8 = Util.area_mean(teq_8_ml).groupby("time.year").mean("time")
annual_mean12 = Util.area_mean(teq_12_ml).groupby("time.year").mean("time")
annual_mean16 = Util.area_mean(teq_16_ml).groupby("time.year").mean("time")

annual_mean1.plot(label="Annual Mean 1x CO2")
annual_mean2.plot(label="Annual Mean 2x CO2")
annual_mean3.plot(label="Annual Mean 3x CO2")
#annual_mean4.plot(label="Annual Mean 4x CO2")
annual_mean6.plot(label="Annual Mean 6x CO2")
annual_mean8.plot(label="Annual Mean 8x CO2")
annual_mean12.plot(label="Annual Mean 12x CO2")
annual_mean16.plot(label="Annual Mean 16x CO2")

rolling_mean1 = annual_mean1.rolling(year=10, center=True).mean()
rolling_mean2 = annual_mean2.rolling(year=10, center=True).mean()
rolling_mean3 = annual_mean3.rolling(year=10, center=True).mean()
#rolling_mean4 = annual_mean4.rolling(year=10, center=True).mean()
rolling_mean6 = annual_mean6.rolling(year=10, center=True).mean()
rolling_mean8 = annual_mean8.rolling(year=10, center=True).mean()
rolling_mean12 = annual_mean12.rolling(year=10, center=True).mean()
rolling_mean16 = annual_mean16.rolling(year=10, center=True).mean()

rolling_mean1.plot(c="k", linestyle='--', label="10-Year Rolling Mean 1x CO2")
rolling_mean2.plot(c="k", linestyle='-', label="10-Year Rolling Mean 2x CO2")
rolling_mean3.plot(c="k", linestyle=':', label="10-Year Rolling Mean 3x CO2")
#rolling_mean4.plot(c="k", linestyle='-.', label="10-Year Rolling Mean 4x CO2")
rolling_mean6.plot(c="k", linestyle='-', label="10-Year Rolling Mean 6x CO2")
rolling_mean8.plot(c="k", linestyle=':', label="10-Year Rolling Mean 8x CO2")
rolling_mean12.plot(c="k", linestyle='-.', label="10-Year Rolling Mean 12x CO2")
rolling_mean16.plot(c="k", linestyle='-.', label="10-Year Rolling Mean 16x CO2")

plt.xlabel('Year')
plt.ylabel('Temperature (K)')
plt.title('Global Mean Temperature for Various CO2 Levels')
plt.legend()

# %%
annual_mean1 = annual_mean1.sel(year=slice(101, 550))
annual_mean2 = annual_mean2.sel(year=slice(101, 550))
annual_mean3 = annual_mean3.sel(year=slice(101, 550))
annual_mean4 = annual_mean4.sel(year=slice(101, 550))
annual_mean6 = annual_mean6.sel(year=slice(101, 550))
annual_mean8 = annual_mean8.sel(year=slice(101, 550))
annual_mean12 = annual_mean12.sel(year=slice(101, 550))
annual_mean16 = annual_mean16.sel(year=slice(101, 550))

annual_mean1.plot(label="Annual Mean 1x CO2")
annual_mean2.plot(label="Annual Mean 2x CO2")
annual_mean3.plot(label="Annual Mean 3x CO2")
annual_mean4.plot(label="Annual Mean 4x CO2")
annual_mean6.plot(label="Annual Mean 6x CO2")
annual_mean8.plot(label="Annual Mean 8x CO2")
annual_mean12.plot(label="Annual Mean 12x CO2")
annual_mean16.plot(label="Annual Mean 16x CO2")

plt.xlabel('Year')
plt.ylabel('Temperature (K)')
plt.title('Global Mean Temperature for Various CO2 Levels')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
co2_x = [1, 2, 3, 4, 6, 8, 12,16]

mean_temp_1 = annual_mean1.mean().compute().values
mean_temp_2 = annual_mean2.mean().compute().values
mean_temp_3 = annual_mean3.mean().compute().values
mean_temp_4 = annual_mean4.mean().compute().values
mean_temp_6 = annual_mean6.mean().compute().values
mean_temp_8 = annual_mean8.mean().compute().values
mean_temp_12 = annual_mean12.mean().compute().values
mean_temp_16 = annual_mean16.mean().compute().values

mean_temperatures = [mean_temp_1, mean_temp_2, mean_temp_3, mean_temp_4, mean_temp_6, mean_temp_8, mean_temp_12, mean_temp_16]

plt.figure(figsize=(10, 6))
plt.plot(co2_x, [annual_mean1.mean().compute().values, annual_mean2.mean().compute().values, 
                              annual_mean3.mean().compute().values, annual_mean4.mean().compute().values, 
                              annual_mean6.mean().compute().values, annual_mean8.mean().compute().values, 
                              annual_mean12.mean().compute().values, annual_mean16.mean().compute().values], marker='o', linestyle='-', color='b')

plt.xlabel('CO2 Concentration (x CO2)')
plt.ylabel('Annual Mean Temperature (K)')
plt.title('Annual Mean Temperature vs CO2 Concentration')
plt.grid(True)
plt.show()

# %% [markdown]
# TEMPERATURE ANOMALIES TO x1 CO2

# %%
anomaly_2 = annual_mean2 - annual_mean1
anomaly_3 = annual_mean3 - annual_mean1
anomaly_4 = annual_mean4 - annual_mean1
anomaly_6 = annual_mean6 - annual_mean1
anomaly_8 = annual_mean8 - annual_mean1
anomaly_12 = annual_mean12 - annual_mean1
anomaly_16 = annual_mean16 - annual_mean1

anomaly_2.plot(label="2x - 1x CO2", color='green')
anomaly_3.plot(label="3x - 1x CO2", color='blue')
anomaly_4.plot(label="4x - 1x CO2", color='red')
anomaly_6.plot(label="6x - 1x CO2", color='purple')
anomaly_8.plot(label="8x - 1x CO2", color='orange')
anomaly_12.plot(label="12x - 1x CO2", color='brown')
anomaly_16.plot(label="16x - 1x CO2", color='pink')

plt.xlabel('Year')
plt.ylabel('Temperature Anomaly (K)')
plt.title('Temperature Anomaly for Various CO2 Levels')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# 2D MAPS FOR ALL SIMULATIONS

# %%
import cartopy.crs as ccrs

t_plot= teq_16_ml.mean(dim='time')- teq_1_ml.mean(dim='time')

title = "Temperature Difference (16xCO2 - 1xCO2, ML)"
fig,ax = Util.v_plot_map_2D(t_plot, title=title, units="K", nx=2, ny=2, nn=1, cmap='plasma', vmin=0, vmax=50)

ax.set_title(title, fontsize=9)
# Out:
# Text(0.5, 1.0, 'Temperature Difference (16xCO2 - 1xCO2, ML)')

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Load land-sea mask
mask_ds = xr.open_dataset("/home/ighirardo/work/plasim/exp/test_h_ml/lsm.nc")
land_sea_mask = mask_ds['paleo_stddev_subgrid_topo']

# --- Assuming teq_ml_1 is already loaded ---
# 1. Time average
teq_1_ml = teq_1_ml.mean(dim='time')

# 2. Roll longitudes and reassign to -180 to 180
teq_1_ml= teq_1_ml.roll(lon=len(teq_1_ml['lon']) // 2, roll_coords=True)
new_lon = np.linspace(-180, 180, len(teq_1_ml['lon']), endpoint=False)
teq_1_ml['lon'] = new_lon

# 3. Roll land-sea mask too (to match longitude)
mask_ds = mask_ds.roll(lon=len(mask_ds['lon']) // 2, roll_coords=True)
mask_ds['lon'] = np.linspace(-180, 180, len(mask_ds['lon']), endpoint=False)
land_sea_mask = mask_ds['paleo_stddev_subgrid_topo']

# 4. Plot
fig = plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())

teq_1_ml.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='Blues',
              cbar_kwargs={'label': 'frac.'}, vmin=0, vmax=1)

ax.contour(mask_ds['lon'], mask_ds['lat'], land_sea_mask,
           levels=[0.5], colors='black', linewidths=1, transform=ccrs.PlateCarree())

ax.set_title("Sea Ice Cover for 3xC02, ML")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 t_plot= teq_1_ml.mean(dim='time')
#       5 title = "Temperature Difference (16xCO₂ - 1xCO₂, ML)"
# ----> 6 fig,ax = Util.plot_map_2D(t_plot, title=title, units="K", nx=2, ny=2, nn=1, cmap='coolwarm', cbar_kwargs={'label': 'frac.'}, vmin=0, vmax=1)
#       8 ax.set_title(title, fontsize=9)
#
# TypeError: plot_map_2D() got an unexpected keyword argument 'cbar_kwargs'

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import Util
import importlib
importlib.reload(Util)
# Out:
# <module 'Util' from '/work/users/ighirardo/plasim/exp/Util.py'>

# %%
# Creazione della figura e della griglia 4x2
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 20), subplot_kw={'projection': ccrs.PlateCarree()})
fig.suptitle('Temperature at Equilibrium for Various CO2 Levels', fontsize=16)

# Aggiustamento degli spazi tra i subplot per evitare sovrapposizioni
fig.subplots_adjust(wspace=0.1, hspace=0.3)  # Spaziatura orizzontale e verticale

# Creazione dei plot delle simulazioni, con colorbar singola per riga
img1 = Util.new_plot_map_2D(teq_1.mean(dim='time'), title="1xCO2", units="K", nx=4, ny=2, nn=1, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[0, 0].set_title("1xCO2")

img2 = Util.new_plot_map_2D(teq_2.mean(dim='time'), title="2xCO2", units="K", nx=4, ny=2, nn=2, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[0, 1].set_title("2xCO2")

img3 = Util.new_plot_map_2D(teq_3.mean(dim='time'), title="3xCO2", units="K", nx=4, ny=2, nn=3, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[1, 0].set_title("3xCO2")

img4 = Util.new_plot_map_2D(teq_4.mean(dim='time'), title="4xCO2", units="K", nx=4, ny=2, nn=4, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[1, 1].set_title("4xCO2")

img5 = Util.new_plot_map_2D(teq_6.mean(dim='time'), title="6xCO2", units="K", nx=4, ny=2, nn=5, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[2, 0].set_title("6xCO2")

img6 = Util.new_plot_map_2D(teq_8.mean(dim='time'), title="8xCO2", units="K", nx=4, ny=2, nn=6, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[2, 1].set_title("8xCO2")

img7 = Util.new_plot_map_2D(teq_12.mean(dim='time'), title="12xCO2", units="K", nx=4, ny=2, nn=7, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[3, 0].set_title("12xCO2")

img8 = Util.new_plot_map_2D(teq_16.mean(dim='time'), title="16xCO2", units="K", nx=4, ny=2, nn=8, fig=fig, cmap='coolwarm', show_colorbar=False)
axes[3, 1].set_title("16xCO2")

# Aggiunta di una colorbar centrale per ogni riga
# Aggiunta di una colorbar verticale per ogni riga, posizionata centralmente
fig.colorbar(img1[2], ax=axes[0, :], orientation='vertical', fraction=0.05, pad=0.05).set_label('Temperature (K)')
fig.colorbar(img3[2], ax=axes[1, :], orientation='vertical', fraction=0.05, pad=0.05).set_label('Temperature (K)')
fig.colorbar(img5[2], ax=axes[2, :], orientation='vertical', fraction=0.05, pad=0.05).set_label('Temperature (K)')
fig.colorbar(img7[2], ax=axes[3, :], orientation='vertical', fraction=0.05, pad=0.05).set_label('Temperature (K)')

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np

# Creazione della figura e della griglia 4x2 con subplot quadrati
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10, 15), subplot_kw={'projection': ccrs.PlateCarree()})
fig.suptitle('Temperature at Equilibrium for Various CO2 Levels', fontsize=16)

# Aggiustamento degli spazi tra i subplot per uniformare le dimensioni
fig.subplots_adjust(wspace=0.05, hspace=0.1)

# Creazione della lista delle simulazioni e dei titoli
simulations = [teq_1, teq_2, teq_3, teq_4, teq_6, teq_8, teq_12, teq_16]
titles = ["1xCO2", "2xCO2", "3xCO2", "4xCO2", "6xCO2", "8xCO2", "12xCO2", "16xCO2"]

# Determinare il range globale della colorbar
vmin = min(sim.mean(dim='time').values.min() for sim in simulations)
vmax = max(sim.mean(dim='time').values.max() for sim in simulations)

# Creazione dei plot e salvataggio degli oggetti immagine
images = []
for i, (sim, title) in enumerate(zip(simulations, titles)):
    row, col = divmod(i, 2)
    img = Util.new_plot_map_2D(sim.mean(dim='time'), title=title, units="K", nx=4, ny=2, nn=i+1, fig=fig, cmap='coolwarm', show_colorbar=False)
    axes[row, col].set_title(title)
    
    # Salvare l'immagine per regolare la colorbar successivamente
    images.append(img[2])  # Supponendo che img[2] sia l'oggetto mappable

# Applicare lo stesso range di colori a tutte le immagini
for im in images:
    im.set_clim(vmin, vmax)

# Posizione centrale per l'unica colorbar
cbar_ax = fig.add_axes([0.42, 0.08, 0.2, 0.02])  # (left, bottom, width, height)
cbar = fig.colorbar(images[0], cax=cbar_ax, orientation='horizontal')
cbar.set_label('Temperature (K)')

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np

# Creazione della figura e della griglia 4x2 con subplot più compatti
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10, 12), subplot_kw={'projection': ccrs.PlateCarree()})
fig.suptitle('Temperature at Equilibrium for Various CO2 Levels', fontsize=16)

# Aggiustamento degli spazi tra i subplot per eliminare quadrati vuoti
fig.subplots_adjust(wspace=0.1, hspace=0.2)

# Creazione della lista delle simulazioni e dei titoli
simulations = [teq_1, teq_2, teq_3, teq_4, teq_6, teq_8, teq_12, teq_16]
titles = ["1xCO2", "2xCO2", "3xCO2", "4xCO2", "6xCO2", "8xCO2", "12xCO2", "16xCO2"]

# Determinare il range globale della colorbar
vmin = min(sim.mean(dim='time').values.min() for sim in simulations)
vmax = max(sim.mean(dim='time').values.max() for sim in simulations)

# Creazione dei plot e salvataggio degli oggetti immagine
images = []
for i, (sim, title) in enumerate(zip(simulations, titles)):
    row, col = divmod(i, 2)
    img = Util.new_plot_map_2D(sim.mean(dim='time'), title=title, units="K", nx=4, ny=2, nn=i+1, fig=fig, cmap='coolwarm', show_colorbar=False)
    axes[row, col].set_title(title)
    
    # Salvare l'immagine per regolare la colorbar successivamente
    images.append(img[2])  # Supponendo che img[2] sia l'oggetto mappable

# Applicare lo stesso range di colori a tutte le immagini
for im in images:
    im.set_clim(vmin, vmax)

# Rimuovere i subplot vuoti se ci sono
for ax in axes.flat[len(simulations):]:
    ax.remove()

# Posizione centrale per l'unica colorbar
cbar_ax = fig.add_axes([0.25, 0.05, 0.5, 0.02])  # (left, bottom, width, height)
cbar = fig.colorbar(images[0], cax=cbar_ax, orientation='horizontal')
cbar.set_label('Temperature (K)')

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np

# Creazione della figura e della griglia 4x2 con subplot più compatti
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10, 12), subplot_kw={'projection': ccrs.PlateCarree()})
fig.suptitle('Temperature at Equilibrium for Various CO2 Levels', fontsize=16)

# Aggiustamento degli spazi tra i subplot per eliminare quadrati vuoti
fig.subplots_adjust(wspace=0.1, hspace=0.2)

# Creazione della lista delle simulazioni e dei titoli
simulations = [teq_1, teq_2, teq_3, teq_4, teq_6, teq_8, teq_12, teq_16]
titles = ["1xCO2", "2xCO2", "3xCO2", "4xCO2", "6xCO2", "8xCO2", "12xCO2", "16xCO2"]

# Determinare il range globale della colorbar
vmin = min(sim.mean(dim='time').values.min() for sim in simulations)
vmax = max(sim.mean(dim='time').values.max() for sim in simulations)

# Creazione dei plot e salvataggio degli oggetti immagine
images = []
for i, (sim, title) in enumerate(zip(simulations, titles)):
    row, col = divmod(i, 2)
    img = Util.new_plot_map_2D(sim.mean(dim='time'), title=title, units="K", nx=4, ny=2, nn=i+1, fig=fig, cmap='coolwarm', show_colorbar=False)
    axes[row, col].set_title(title)
    
    # Salvare l'immagine per regolare la colorbar successivamente
    images.append(img[2])  # Supponendo che img[2] sia l'oggetto mappable

# Applicare lo stesso range di colori a tutte le immagini
for im in images:
    im.set_clim(vmin, vmax)

# Rimuovere i subplot vuoti se ci sono
for ax in axes.flat[len(simulations):]:
    ax.remove()

# Posizione centrale per l'unica colorbar
cbar_ax = fig.add_axes([0.25, 0.05, 0.5, 0.02])  # (left, bottom, width, height)
cbar = fig.colorbar(images[0], cax=cbar_ax, orientation='horizontal')
cbar.set_label('Temperature (K)')

plt.show()
